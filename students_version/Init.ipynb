# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# cd /work
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     # Deepnote's notebook 6.5.5 requires pyzmq<25.0.0
#     pip install -r ./requirements.txt "pyzmq<25.0.0"
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Looking in indexes: https://pypi.org/simple, https://drake-packages.csail.mit.edu/whl/nightly
# Collecting pyzmq<25.0.0
#   Downloading pyzmq-24.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.4 MB/s eta 0:00:00
# Collecting underactuated==2025.2.16
#   Downloading underactuated-2025.2.16-py3-none-any.whl (986 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 986.3/986.3 KB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: mpld3>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.5.10)
# Requirement already satisfied: ipywidgets>=8 in /usr/local/lib/python3.10/dist-packages (from underactuated==2025.2.16->-r ./requirements.txt (line 3)) (8.1.5)
# Collecting numpy>2.0.0
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 41.2 MB/s eta 0:00:00
# Requirement already satisfied: drake>=1.36.0 in /usr/local/lib/python3.10/dist-packages (from underactuated==2025.2.16->-r ./requirements.txt (line 3)) (1.36.0)
# Requirement already satisfied: pydot>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from underactuated==2025.2.16->-r ./requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: matplotlib[mplot3d]>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from underactuated==2025.2.16->-r ./requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from drake>=1.36.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (8.31.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (4.0.13)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (3.0.13)
# WARNING: matplotlib 3.10.0 does not provide the extra 'mplot3d'
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (24.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (4.55.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mpld3>=0.5.1->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (3.1.5)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (3.0.48)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: stack_data in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.1.7)
# Requirement already satisfied: typing_extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib[mplot3d]>=3.7.0->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mpld3>=0.5.1->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /toolkit-cache/0.2.21/python3.10/kernel-libs/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.2.13)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8->underactuated==2025.2.16->-r ./requirements.txt (line 3)) (2.1.0)
# Installing collected packages: pyzmq, numpy, underactuated
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 26.2.0
#     Not uninstalling pyzmq at /usr/local/lib/python3.10/dist-packages, outside environment /root/venv
#     Can't uninstall 'pyzmq'. No files were found to uninstall.
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Not uninstalling numpy at /usr/local/lib/python3.10/dist-packages, outside environment /root/venv
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: underactuated
#     Found existing installation: underactuated 2025.1.3
#     Not uninstalling underactuated at /usr/local/lib/python3.10/dist-packages, outside environment /root/venv
#     Can't uninstall 'underactuated'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deepnote-toolkit 0.1.0 requires numpy<2,>=1.19; python_version >= "3.8" and python_version < "4.0", but you have numpy 2.2.6 which is incompatible.
# deepnote-toolkit 0.1.0 requires numpy<2,>=1.21; python_version >= "3.9" and python_version < "4.0", but you have numpy 2.2.6 which is incompatible.
# deepnote-toolkit 0.1.0 requires numpy<2,>=1.23; python_version >= "3.10" and python_version < "4.0", but you have numpy 2.2.6 which is incompatible.
# deepnote-toolkit 0.1.0 requires pandas<2.2,>=1.2.5; python_version < "3.12", but you have pandas 2.2.3 which is incompatible.
# Successfully installed numpy-2.2.6 pyzmq-24.0.1 underactuated-2025.2.16
